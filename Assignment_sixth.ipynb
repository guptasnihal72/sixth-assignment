# %% [markdown]
# #**TASK 1 :**
# **Problem Statement**
#
# Write code to position 5 equal-sized (50 X 50px) boxes A, B, C, D, and E as follows,
#  1. box A 200px from the left, and 200px  rom the top of the viewpor.
#
# 2.  box B -30px left, and -30px above from the center of box.
# 3. box B -30px right, and -30px above from the center of box.
# 4. box B -30px left, and -30px below from the center of box.
# 5. box B -30px right, and -30px below from the center of box A.
#
# - Ans
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         .main{
#             max-width: 500px;
#             width: 100%;
#             height: 500px;
#             border: 2px solid red;
#             margin: auto;
#         }
#         .main .first{
#             width: 40%;
#             height:200px;
#             border: 2px solid rgb(137, 17, 188);
#             margin:150px auto;
#             align-items: center;
#             justify-content: center;
#             background-color: rgb(179, 0, 255);
#         }
#         .main .first P{
#             text-align: center;
#             font-size: 30px;
#             font-weight: bold;
#             font-family: Arial, Helvetica, sans-serif;
#             margin-top:70px ;
#         }
#         .main .second{
#             width: 40%;
#             height:200px;
#             margin-top: -500px;
#             margin-left: 5px;
#             border: 2px solid rgb(137, 17, 188);
#             background-color: rgb(179, 0, 255);
#         }
#         .main .second P{
#             text-align: center;
#             font-size: 30px;
#             font-weight: bold;
#             font-family: Arial, Helvetica, sans-serif;
#             margin-top: 70px;
#         }
#         .main .third{
#             width: 40%;
#             height:200px;
#             margin-top: -205px;
#             margin-left: 290px;
#             /* margin-right: 5px; */
#             border: 2px solid rgb(137, 17, 188);
#             background-color: rgb(179, 0, 255);
#         }
#         .main .third P{
#             text-align: center;
#             font-size: 30px;
#             font-weight: bold;
#             font-family: Arial, Helvetica, sans-serif;
#             margin-top: 70px;
#         }
#         .main .fourth{
#             width: 40%;
#             height:200px;
#             margin-top: 85px;
#             margin-left: 5px;
#             /* margin-right: 5px; */
#             border: 2px solid rgb(137, 17, 188);
#             background-color: rgb(179, 0, 255);
#         }
#         .main .fourth P{
#             text-align: center;
#             font-size: 30px;
#             font-weight: bold;
#             font-family: Arial, Helvetica, sans-serif;
#             margin-top: 70px;
#         }
#         .main .five{
#             width: 40%;
#             height:200px;
#             margin-top: -205px;
#             margin-left: 290px;
#             /* margin-right: 5px; */
#             border: 2px solid rgb(137, 17, 188);
#             background-color: rgb(179, 0, 255);
#         }
#         .main .five P{
#             text-align: center;
#             font-size: 30px;
#             font-weight: bold;
#             font-family: Arial, Helvetica, sans-serif;
#             margin-top: 70px;
#         }
#
#
#     </style>
# </head>
# <body>
#     <div class="main">
#         <div class="first">
#             <p>A</p>
#         </div>
#         <div class="second">
#             <p>B</p>
#         </div>
#         <div class="third">
#             <p>c</p>
#         </div>
#         <div class="fourth">
#             <p>D</p>
#         </div>
#         <div class="five">
#             <p>D</p>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# #** Task 2 :**
# **Problem Statement**
#
# Explain the difference between Absolute and Relative positioning.
#
# **Absolute Positioning**
# - When an element is positioned absolutely, it is removed from the normal document flow and positioned relative to its nearest positioned ancestor (an ancestor with a position value other than static). If no such ancestor exists, it is positioned relative to the initial containing block (usually the <html> element).
# **Relative Positioning**
# -  When an element is positioned relatively, it remains in the normal document flow, but you can adjust its position relative to its original position using the top, right, bottom, and left properties

# %% [markdown]
# #** Task 3:**
#
# **Problem Statement**
#
# Create a card as shown in the picture below. (You can use CSS float property only for layout)?
# - Ans
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         .main{
#             border: 2px solid black;
#             height: auto;
#             width: 80%;
#             margin: auto;
#         }
#         #img1{
#             float: right;
#             margin: 10px 25px 10px 25px;
#
#         }
#         .main p{
#             margin: 20px;
#             text-align: justify;
#         }
#         .main h1{
#             margin: 10px 30px;
#         }
#     </style>
# </head>
# <body>
#     <div class="main">
#         <img src="/img/second.jpg" id="img1" width="200px" height="200px">
#         <h1> The Earth !!!</h1>
#         <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Nobis recusandae sapiente illo, eligendi eum quaerat excepturi quae placeat aut dolorum quia animi commodi ex. Quidem, saepe, ducimus blanditiis exercitationem unde eos odit ab consequuntur odio nemo hic. Omnis quis distinctio corporis ut nemo debitis veniam eveniet eligendi accusamus incidunt a voluptatibus esse modi aliquid sequi earum repellendus repellat alias, delectus fugit quo. Labore possimus rerum aliquid culpa. Esse repellat porro consequuntur, non unde tempora quas consequatur ab enim nemo vitae delectus, earum debitis, rerum eveniet architecto perspiciatis minus eligendi reiciendis? Iste culpa atque quisquam quae, reiciendis odio, mollitia aspernatur sunt quo eius architecto praesentium laborum magni laudantium? Corrupti maxime velit id consequatur impedit repellat iure pariatur sequi repudiandae, aperiam quibusdam iste nesciunt nam sed, atque totam? Error laudantium quidem sit quibusdam excepturi consequuntur velit rem officia ipsam repellendus, sed blanditiis! Sint, ipsa itaque error a vel enim illum ullam! Velit, eligendi! Dicta fuga excepturi molestias temporibus corrupti ipsa minima natus incidunt eveniet possimus illo ipsam, aut, veniam necessitatibus nostrum voluptatum amet hic deleniti reprehenderit esse a ratione doloribus! Sint earum optio architecto esse incidunt rem est consequatur distinctio ea repellat placeat ullam eius ad, libero voluptas, beatae dolores aspernatur itaque?</p>
#     </div>
#
# </body>
# </html>

# %% [markdown]
# # **Task 4:**
#
# **Problem Statement**
#
# Create a simple header that sticks to the top of a webpage upon scrolling.
# - Ans
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>*{
#         margin: 0;
#         padding: 0;
#     }
#          .main{
#             width: 100%;
#             height: 80px;
#             /* border: 1px solid red; */
#             display: flex;
#             background-color: rgb(42, 42, 42);
#             position: fixed;
#          }
#         .main .first-content img{
#             width: 80px;
#             height: 80px;
#             padding-left: 100px;
#         }
#         .main .second-content{
#            /* border: 1px solid red; */
#            width: 100%;
#            line-height: 80px;
#         }
#         .main .second-content ul{
#             float: right;
#             display: flex;
#         }
#         .main .second-content ul li{
#             margin-left: 20px;
#             list-style-type: none;
#             padding-right: 50px;
#         }
#         .main .second-content ul li a{
#             text-decoration: none;
#             font-weight: bold;
#             text-transform: capitalize;
#             font-family: Arial, Helvetica, sans-serif;
#             color: rgb(120, 108, 108);
#             background-color: rgb(42, 42, 42);
#             padding: 15px;
#             border-radius: 10px;
#         }
#         .main .first-content{
#             line-height: 80px;
#             padding-left: 0px;
#             font-size: 50px;
#             font-weight: bold;
#             font-family: Arial, Helvetica, sans-serif;
#             color: white;
#         }
#         .main .second-content ul .first{
#             color: white;
#         }
#         .main .second-content ul li a:hover{
#             color: white;
#             background-color: rgb(121, 117, 117);
#         }
#         .main .second-content ul .last{
#             border: 3px solid goldenrod;
#             color: goldenrod;
#         }
#         .main .second-content ul .last:hover{
#             background-color: goldenrod;
#             color: black;
#             border: 3px solid goldenrod;
#         }
#         .second-main{
#             padding-top: 80px;
#             border: 3px solid black;
#         }
#         .second-main h1{
#             padding-left: 30px;
#             line-height: 60px;
#         }
#         .second-main p{
#             /* border: 2px solid red; */
#             width: 98%;
#             margin: auto;
#             font-size: 20px;
#             text-align: justify;
#         }
#
#     </style>
# </head>
# <body>
#     <div class="main">
#         <div class="first-content">
#             <p>LOGO</p>
#         </div>
#         <div class="second-content">
#             <ul>
#                 <li><a href=""  class="first">Home</a></li>
#                 <li><a href="">Pricing</a></li>
#                 <li><a href="">Contact</a></li>
#                 <li><a href="">terms And condition</a></li>
#                 <li><a href="" class="last">Get started</a></li>
#             </ul>
#         </div>
#     </div>
#     <div class="second-main">
#         <h1>Heading 1<Sup>st</Sup></h1>
#          <p>Lorem ipsum dolor sit amet consectetur, adipisicing elit. Magnam, ea eius voluptate dignissimos fugit expedita laudantium. Praesentium beatae vero, commodi, voluptatum debitis nisi dolores voluptatem sequi inventore qui eveniet cupiditate velit doloribus reprehenderit dolore hic cumque ea, totam dignissimos? Ab ducimus aliquid suscipit eius ullam! Voluptatum accusantium saepe quo harum magni consequuntur aut quia illum aliquam temporibus? Provident possimus fuga velit, voluptas vero, tenetur sint eum corrupti quod, iusto voluptatum odit. Provident, ut. Nostrum veritatis quibusdam ad suscipit error harum animi fugiat laborum, placeat aliquam minus accusantium laboriosam rem tenetur voluptatem est cumque necessitatibus. Ratione numquam placeat cumque minus porro.</p>
#          <h1>Heading 1<Sup>st</Sup></h1>
#          <p>Lorem ipsum dolor sit amet consectetur, adipisicing elit. Magnam, ea eius voluptate dignissimos fugit expedita laudantium. Praesentium beatae vero, commodi, voluptatum debitis nisi dolores voluptatem sequi inventore qui eveniet cupiditate velit doloribus reprehenderit dolore hic cumque ea, totam dignissimos? Ab ducimus aliquid suscipit eius ullam! Voluptatum accusantium saepe quo harum magni consequuntur aut quia illum aliquam temporibus? Provident possimus fuga velit, voluptas vero, tenetur sint eum corrupti quod, iusto voluptatum odit. Provident, ut. Nostrum veritatis quibusdam ad suscipit error harum animi fugiat laborum, placeat aliquam minus accusantium laboriosam rem tenetur voluptatem est cumque necessitatibus. Ratione numquam placeat cumque minus porro.</p>
#          <h1>Heading 1<Sup>st</Sup></h1>
#          <p>Lorem ipsum dolor sit amet consectetur, adipisicing elit. Magnam, ea eius voluptate dignissimos fugit expedita laudantium. Praesentium beatae vero, commodi, voluptatum debitis nisi dolores voluptatem sequi inventore qui eveniet cupiditate velit doloribus reprehenderit dolore hic cumque ea, totam dignissimos? Ab ducimus aliquid suscipit eius ullam! Voluptatum accusantium saepe quo harum magni consequuntur aut quia illum aliquam temporibus? Provident possimus fuga velit, voluptas vero, tenetur sint eum corrupti quod, iusto voluptatum odit. Provident, ut. Nostrum veritatis quibusdam ad suscipit error harum animi fugiat laborum, placeat aliquam minus accusantium laboriosam rem tenetur voluptatem est cumque necessitatibus. Ratione numquam placeat cumque minus porro.</p>
#          <h1>Heading 1<Sup>st</Sup></h1>
#          <p>Lorem ipsum dolor sit amet consectetur, adipisicing elit. Magnam, ea eius voluptate dignissimos fugit expedita laudantium. Praesentium beatae vero, commodi, voluptatum debitis nisi dolores voluptatem sequi inventore qui eveniet cupiditate velit doloribus reprehenderit dolore hic cumque ea, totam dignissimos? Ab ducimus aliquid suscipit eius ullam! Voluptatum accusantium saepe quo harum magni consequuntur aut quia illum aliquam temporibus? Provident possimus fuga velit, voluptas vero, tenetur sint eum corrupti quod, iusto voluptatum odit. Provident, ut. Nostrum veritatis quibusdam ad suscipit error harum animi fugiat laborum, placeat aliquam minus accusantium laboriosam rem tenetur voluptatem est cumque necessitatibus. Ratione numquam placeat cumque minus porro.</p>
#          <h1>Heading 1<Sup>st</Sup></h1>
#          <p>Lorem ipsum dolor sit amet consectetur, adipisicing elit. Magnam, ea eius voluptate dignissimos fugit expedita laudantium. Praesentium beatae vero, commodi, voluptatum debitis nisi dolores voluptatem sequi inventore qui eveniet cupiditate velit doloribus reprehenderit dolore hic cumque ea, totam dignissimos? Ab ducimus aliquid suscipit eius ullam! Voluptatum accusantium saepe quo harum magni consequuntur aut quia illum aliquam temporibus? Provident possimus fuga velit, voluptas vero, tenetur sint eum corrupti quod, iusto voluptatum odit. Provident, ut. Nostrum veritatis quibusdam ad suscipit error harum animi fugiat laborum, placeat aliquam minus accusantium laboriosam rem tenetur voluptatem est cumque necessitatibus. Ratione numquam placeat cumque minus porro.</p>
#
#
#     </div>
#
# </body>
# </html>

# %% [markdown]
# **#Task 5:**
#
# **Problem Statement**
#
# Explain the z-index, with a code example.
# - ans
#
# The z-index property in CSS is used to control the stacking order of overlapping elements on a webpage. It determines which elements appear on top of others when they overlap. The z-index only works on positioned elements (i.e., elements that have a position value of relative, absolute, fixed, or sticky).
#
# **example**
# <!DOCTYPE html>
# <html lang="hi">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Z-Index उदाहरण</title>
#     <style>
#         .box {
#             width: 200px;
#             height: 200px;
#             position: absolute;
#         }
#         .box1 {
#             background-color: red;
#             z-index: 1;
#             top: 50px;
#             left: 50px;
#         }
#         .box2 {
#             background-color: blue;
#             z-index: 2;
#             top: 100px;
#             left: 100px;
#         }
#         .box3 {
#             background-color: green;
#             z-index: 3;
#             top: 150px;
#             left: 150px;
#         }
#     </style>
# </head>
# <body>
#     <div class="box box1"></div>
#     <div class="box box2"></div>
#     <div class="box box3"></div>
# </body>
# </html>
